# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinashvns/numpy-practice/blob/main/NumPy_Practice/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NUMPY Creation

# %%
import numpy as np
a=np.array([1,2,3,4,5])

print(a)
print(type(a))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
