# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinashvns/numpy-practice/blob/main/NumPy_Practice/array_properties.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🧠 Array Properties (ML ke liye compulsory)

# %%
import numpy as np

a = np.array([10, 20, 30, 40])

print("Array:", a)
print("Shape:", a.shape)
print("Size:", a.size)
print("Datatype:", a.dtype)
# Out:
# Array: [10 20 30 40]
# Shape: (4,)
# Size: 4
# Datatype: int64
